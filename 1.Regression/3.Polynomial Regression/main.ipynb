# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('real_estate.csv')

# %%
dataset.drop_duplicates()
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
X = dataset.iloc[:,2:-1].values
y = dataset.iloc[:,-1].values

# %%
X
# Out:
# array([[ 32.     ,  84.87882,  10.     ,  24.98298, 121.54024],
#        [ 19.5    , 306.5947 ,   9.     ,  24.98034, 121.53951],
#        [ 13.3    , 561.9845 ,   5.     ,  24.98746, 121.54391],
#        ...,
#        [ 18.8    , 390.9696 ,   7.     ,  24.97923, 121.53986],
#        [  8.1    , 104.8101 ,   5.     ,  24.96674, 121.54067],
#        [  6.5    ,  90.45606,   9.     ,  24.97433, 121.5431 ]])

# %%
y
# Out:
# array([ 37.9,  42.2,  47.3,  54.8,  43.1,  32.1,  40.3,  46.7,  18.8,
#         22.1,  41.4,  58.1,  39.3,  23.8,  34.3,  50.5,  70.1,  37.4,
#         42.3,  47.7,  29.3,  51.6,  24.6,  47.9,  38.8,  27. ,  56.2,
#         33.6,  47. ,  57.1,  22.1,  25. ,  34.2,  49.3,  55.1,  27.3,
#         22.9,  25.3,  47.7,  46.2,  15.9,  18.2,  34.7,  34.1,  53.9,
#         38.3,  42. ,  61.5,  13.4,  13.2,  44.2,  20.7,  27. ,  38.9,
#         51.7,  13.7,  41.9,  53.5,  22.6,  42.4,  21.3,  63.2,  27.7,
#         55. ,  25.3,  44.3,  50.7,  56.8,  36.2,  42. ,  59. ,  40.8,
#         36.3,  20. ,  54.4,  29.5,  36.8,  25.6,  29.8,  26.5,  40.3,
#         36.8,  48.1,  17.7,  43.7,  50.8,  27. ,  18.3,  48. ,  25.3,
#         45.4,  43.2,  21.8,  16.1,  41. ,  51.8,  59.5,  34.6,  51. ,
#         62.2,  38.2,  32.9,  54.4,  45.7,  30.5,  71. ,  47.1,  26.6,
#         34.1,  28.4,  51.6,  39.4,  23.1,   7.6,  53.3,  46.4,  12.2,
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
regressor = PolynomialFeatures(degree=2)
poly_X = regressor.fit_transform(X_train)
poly_X_test = regressor.fit_transform(X_test)

# %%
poly_X
# Out:
# array([[1.00000000e+00, 1.65000000e+01, 2.28801100e+03, ...,
#         6.22944193e+02, 3.03283947e+03, 1.47655526e+04],
#        [1.00000000e+00, 4.50000000e+00, 2.27587700e+03, ...,
#         6.23158359e+02, 3.03330884e+03, 1.47650471e+04],
#        [1.00000000e+00, 3.83000000e+01, 4.39710500e+02, ...,
#         6.23581306e+02, 3.03490539e+03, 1.47705691e+04],
#        ...,
#        [1.00000000e+00, 1.36000000e+01, 4.19734900e+03, ...,
#         6.21946239e+02, 3.03016579e+03, 1.47631807e+04],
#        [1.00000000e+00, 3.59000000e+01, 6.40739100e+02, ...,
#         6.23782094e+02, 3.03546689e+03, 1.47712788e+04],
#        [1.00000000e+00, 6.60000000e+00, 9.04560600e+01, ...,
#         6.23717159e+02, 3.03545749e+03, 1.47727252e+04]])

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg.fit(poly_X,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(poly_X_test)

# %%
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[43.45 45.3 ]
#  [19.3  14.4 ]
#  [42.09 46.  ]
#  [19.39 15.6 ]
#  [41.09 50.2 ]
#  [41.77 38.1 ]
#  [44.09 48.5 ]
#  [38.02 41.4 ]
#  [48.23 51.6 ]
#  [43.83 40.1 ]
#  [45.56 42.  ]
#  [37.52 42.4 ]
#  [41.98 28.5 ]
#  [43.81 39.1 ]
#  [52.49 53.7 ]
#  [39.39 36.8 ]
#  [39.83 40.6 ]
#  [47.39 55.2 ]
#  [39.99 39.3 ]
#  [44.35 44.3 ]
#  [55.67 53.5 ]
#  [24.28 25.3 ]
#  [36.27 22.8 ]
#  [46.33 51.7 ]
#  [52.01 45.5 ]
#  [43.65 34.4 ]
#  [42.99 31.6 ]
#  [25.79 25.9 ]
#  [51.45 49.5 ]
#  [20.5  24.7 ]
#  [42.73 51.7 ]
#  [27.23 29.7 ]
#  [51.67 45.4 ]
#  [40.16 50.5 ]
#  [43.17 26.5 ]
#  [24.19 30.1 ]
#  [45.14 46.1 ]
#  [34.25 28.9 ]
#  [49.69 54.4 ]
#  [ 4.94 15.  ]
#  [57.53 44.9 ]
#  [40.2  29.8 ]
#  [28.94 23.6 ]
#  [45.21 48.  ]
#  [19.91 16.7 ]
#  [42.7  40.9 ]
#  [39.51 40.2 ]
#  [19.58 12.9 ]
#  [25.66 21.3 ]
#  [49.95 62.1 ]
#  [55.03 63.9 ]
#  [39.18 40.3 ]
#  [44.3  42.2 ]
#  [17.82 19.1 ]
#  [24.33 28.4 ]
#  [36.29 28.5 ]
#  [53.5  60.7 ]
#  [39.31 37.5 ]
# ...

# %%
y_test.shape
# Out:
# (83,)

# %%
c = [i for i in range(1,84,1)]         
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)            
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('House Price', fontsize=16)
# Out:
# Text(0, 0.5, 'House Price')

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
r_squared = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
print('r_square_value :',r_squared)
print("Mean Absolute Error (MAE):", mae)
# Out:
# r_square_value : 0.7138767819534414
# Mean Absolute Error (MAE): 5.299712772326298

# %% [markdown]
# ##### R-squared is 0.713, indicating that approximately 71.3% of the variance in the target variable is explained by the model.
# ##### MAE of 5.2 means, on average, model's predictions are off by approximately 5.2 units from the actual values.

# %% [markdown]
# ## Multiple Linear Regression

# %%
multiple_reg = LinearRegression()
multiple_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_2 = multiple_reg.predict(X_test)

# %%
np.set_printoptions(precision=2)
print(np.concatenate((y_pred_2.reshape(len(y_pred_2),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[41.39 45.3 ]
#  [12.36 14.4 ]
#  [41.11 46.  ]
#  [12.17 15.6 ]
#  [40.36 50.2 ]
#  [40.21 38.1 ]
#  [39.9  48.5 ]
#  [33.93 41.4 ]
#  [48.1  51.6 ]
#  [44.58 40.1 ]
#  [45.26 42.  ]
#  [40.66 42.4 ]
#  [40.78 28.5 ]
#  [40.22 39.1 ]
#  [48.75 53.7 ]
#  [35.92 36.8 ]
#  [40.01 40.6 ]
#  [42.36 55.2 ]
#  [41.87 39.3 ]
#  [43.59 44.3 ]
#  [52.19 53.5 ]
#  [30.85 25.3 ]
#  [41.18 22.8 ]
#  [45.93 51.7 ]
#  [47.43 45.5 ]
#  [44.57 34.4 ]
#  [45.07 31.6 ]
#  [28.61 25.9 ]
#  [47.71 49.5 ]
#  [23.63 24.7 ]
#  [42.75 51.7 ]
#  [32.98 29.7 ]
#  [44.01 45.4 ]
#  [36.22 50.5 ]
#  [45.21 26.5 ]
#  [30.79 30.1 ]
#  [47.69 46.1 ]
#  [38.97 28.9 ]
#  [54.02 54.4 ]
#  [10.13 15.  ]
#  [51.28 44.9 ]
#  [34.15 29.8 ]
#  [35.86 23.6 ]
#  [47.99 48.  ]
#  [14.72 16.7 ]
#  [42.57 40.9 ]
#  [44.59 40.2 ]
#  [15.29 12.9 ]
#  [32.7  21.3 ]
#  [46.45 62.1 ]
#  [51.98 63.9 ]
#  [41.29 40.3 ]
#  [49.08 42.2 ]
#  [24.51 19.1 ]
#  [30.87 28.4 ]
#  [35.78 28.5 ]
#  [48.51 60.7 ]
#  [40.5  37.5 ]
# ...

# %%
c = [i for i in range(1,84,1)]         
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2, linestyle="-")
plt.plot(c,y_pred_2, color="red",  linewidth=2, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)            
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('House Price', fontsize=16)
# Out:
# Text(0, 0.5, 'House Price')

# %%
r_squared_2 = r2_score(y_test, y_pred_2)
mae_2 = mean_absolute_error(y_test, y_pred_2)

# %%
print('r_square_value :',r_squared_2)
print("Mean Absolute Error (MAE):", mae_2)
# Out:
# r_square_value : 0.6420691483643814
# Mean Absolute Error (MAE): 5.745927475462705

# %% [markdown]
# ##### R-squared is 0.64, indicating that approximately 64% of the variance in the target variable is explained by the model.
# ##### MAE of 5.74 means, on average, model's predictions are off by approximately 5.74 units from the actual values.
