# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('petrol_consumption.csv')
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
y_test.shape
# Out:
# (10,)

# %%
c = [i for i in range(1,11,1)]         
fig = plt.figure()
plt.plot(c,y_test, color="blue", linewidth=2, linestyle="-")
plt.plot(c,y_pred, color="red",  linewidth=2, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)            
plt.xlabel('Index', fontsize=18)                               
plt.ylabel('Sales', fontsize=16)
# Out:
# Text(0, 0.5, 'Sales')

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
r_squared = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
print('r_square_value :',r_squared)
print("Mean Absolute Error (MAE):", mae)
# Out:
# r_square_value : 0.2259669866062286
# Mean Absolute Error (MAE): 50.8

# %% [markdown]
# ##### R-squared is 0.225, indicating that approximately 22.5% of the variance in the target variable is explained by the model.
# ##### MAE of 50.8 means, on average, model's predictions are off by approximately 50.8 units from the actual values.
